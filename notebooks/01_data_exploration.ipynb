# %% [markdown]
# # Phase 1: Data Exploration (Fake News Detection)
#
# In this notebook, we explore datasets for multilingual fake news detection.
#
# **Target Datasets**:
# - Constraint 2021 (COVID-19 Fake News in English, Hindi, etc.)
# - HuggingFace datasets for multilingual fake news
#
# **Objective**:
# Load the data, analyze class balance, text lengths, and save a clean CSV for the preprocessing stage.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 1. Loading the Dataset
# We will pull a standard fake news dataset from HuggingFace to begin exploration.

# %%
# Example: Loading 'fake_news_english' or similar from HuggingFace
# Note: Replace with actual multilingual dataset like 'checkthat22' if available

try:
    # Loading a sample dataset for demonstration
    dataset = load_dataset("mteb/tweet_sentiment_extraction")
    print(dataset)
except Exception as e:
    print(f"Error loading dataset: {e}")

# %% [markdown]
# ## 2. Basic Analysis
# Let's look at the label distribution.

# %%
def analyze_dataset(ds, split='train'):
    df = ds[split].to_pandas()
    print(f"--- {split.upper()} SPLIT ---")
    print(f"Total records: {len(df)}")
    print("\nMissing values:")
    print(df.isnull().sum())
    
    # Note: 'label' column depends on the actual dataset structure
    if 'label' in df.columns:
        plt.figure(figsize=(6,4))
        sns.countplot(data=df, x='label')
        plt.title('Label Distribution')
        plt.show()
        
    return df

# df_train = analyze_dataset(dataset)
